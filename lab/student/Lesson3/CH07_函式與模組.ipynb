# %% [markdown]
# ## **7.1 自訂函式**

# %% [markdown]
# ### **1. 範例實作：攝氏溫度轉華氏溫度**
# #### 攝氏轉華氏公式：華氏=攝氏*1.8+32。約翰由美國來台遊學，習慣華氏溫度，設計程式讓約翰輸入攝氏溫度，就會顯示華氏溫度。(<ctof.py>)

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ### **⚡2. 延伸練習：體重量測轉換**
# #### 公斤轉英磅公式：英磅=公斤*2.2。瑪麗由英國來台旅遊，飯店提供體重計讓旅客測量體重。設計程式輸入體重公斤數就會計算體重英磅數。(<kgtolb.py>)
#
# ```python
# ---------------------
# 請輸入體重公斤數 : 64
# 你的體重為 : 140.8 磅
# ---------------------
# ```

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ## **7.2 數值函式**

# %% [markdown]
# ### **3. 範例實作：學生均分蘋果**
# #### 今天學校營養午餐的水果是蘋果：設計程式輸入學生人數及蘋果總數，將蘋果平均分給學生，每個學生分到的蘋果數量必須相同，計算每個學生分到的蘋果數及剩餘的蘋果數。(<divmod.py>)

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ### **4. 延伸練習：生活費計算**
# #### 小明父親寄給小明生活費 10000 元，小明每天花費 350 元，計算這筆錢可讓小明維持多天生活，最後剩餘多少錢。(<divmod_cl.py>)

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ### **5. 範例實作：總和及排序**
# #### 為了達到節能減碳目的，爸爸要了解家中最近幾個月用電量情況：設計程式讓爸爸輸入電費，若輸入「-1」表示輸入資料結束，以內建函式顯示最多電費、最少電費、電費總和及將電費由大到小排序。(<sorted.py>)

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ### **6. 延伸練習：家庭支出排序**
# #### 媽媽要了解家中最近 4 個月的家庭支出狀況，設計程式讓媽媽輸入 4 個月家庭支出金額，以內建函式顯示支出最大金額、最小金額、4 個月總支出及支出金額由小到大排序。(<sorted_cl.py>)

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ## **7.3 字串函式**

# %% [markdown]
# ### **7. 範例實作：檢查網址格式**
# #### 設計程式讓使用者輸入網址，程式會檢查輸入的網址格式是否正確。(<startswith.py>)

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ### **8. 延伸練習：圖片檔案名稱格式**
# #### 設計程式讓使用者輸入圖片檔案名稱，程式會檢查輸入的圖片檔案名稱格式是否為 JPG。(<endswith.py>)

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ### **9. 範例實作：以字串排版函式列印成績單**
# #### 一年三班有三位同學，請設計程式幫老師以 rjust 及 ljust 函式整齊列印出班級成績單。(<just.py>)

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ### **⚡10. 延伸練習：業績報表**
# #### 阿德是製藥公司主管，設計程式幫阿德以 rjust 及 ljust 函式整齊列印出製藥公司業務員業績報表。(<just_cl.py>)
#
# ```python
# --------------------------------------
# 姓名     第一季  第二季   第三季  第四季
# 鍾明達   34210    9000  186500   78900
# 鄭廣月   23600   23900  127800  125000
# 何美麗  145000   83400  100000   90000
# --------------------------------------
# ```

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ### **11. 範例實作：轉換日期格式**
# #### 爺爺看不懂以「-」為分隔的日期格式，請設計程式將日期「2017-8-23」轉換為讓爺爺看得懂的「西元 2017 年 8 月 23 日」。(<replace.py>)

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ### **12. 延伸練習：時間格式轉換**
# #### 奶奶看不懂以「:」為分隔的時間格式，請設計程式將時間「10:23:41」轉換為奶奶看得懂的「10 點 23 分 41 秒」。(<replace_cl.py>)

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ## **7.4 亂數模組**

# %% [markdown]
# ### **13. 範例實作：擲骰子遊戲**
# #### 阿寶想玩擲骰子遊戲，但手邊沒有骰子，設計程式讓阿寶按任意鍵再按Enter鍵擲骰子，會顯示 1 到 6 之間的整數亂數代表骰子點數，直接按Enter鍵會結束遊戲。(<randint.py>)

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ### **14. 延伸練習：骰子點數總和**
# #### 小朋友在玩「大富翁」桌遊，遊戲者要連擲三次骰子，然後以總點數決定遊戲前進步數。遊戲時小朋友發現骰子不見了，請設計程式以亂數函式擲骰子三次，然後計算三次骰子點數的總和。(<randint_cl.py>)

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ### **⚡15. 範例實作：大樂透中獎號碼**
#
# #### 大樂透中獎號碼為 6 個 1 到 49 之間的數字加 1 個特別號：撰寫程式取得大樂透中獎號碼，並由小到大顯示方便對獎。(<sample.py>)
#
# ```python
# -------------------------------------------
# 本期大樂透中獎號碼為 : 12, 31, 39, 41, 44, 48
# 本期大樂透特別號為 : 33
# -------------------------------------------
# ```

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ### **16. 延伸練習：骰子點數總和**
# #### 小朋友在玩「大富翁」桌遊，遊戲者要連擲三次骰子，然後以總點數決定遊戲前進步數。遊戲時小朋友發現骰子不見了，請設計程式以亂數函式擲骰子三次，然後計算三次骰子點數的總和。(<randint_cl.py>)

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ## **7.5 時間模組**

# %% [markdown]
# ### **17. 範例實作：列印時間函式所有資訊**
#
# #### 大賽看板上需顯示以中華民國年份表示的現在時刻，給比賽選手做為參考。請設計程式以時間模組列印以中華民國年份表示的現在時刻及節約時間資訊。(<localtime.py>)

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ### **18. 延伸練習：顧客折扣**
# #### 某百貨公司會在一年中的上半年或下半年給予顧客不同折扣，請設計程式以時間模組幫櫃姐判斷今天是上半年還是下半年。(<localtime_cl.py>)

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ### **⚡19. 範例實作：計算執行一百萬次整數運算的時間**
#
# #### 以 perf_counter 函式計算執行一百萬次整數運算的時間。(<clock.py>)

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ### **20. 延伸練習：計算執行一百萬次整數運算的時間**
# #### 以 perf_counter 函式計算執行一百萬次浮點數運算的時間 (浮點數的運算遠比整數運算所花的時間長)。(<clock_cl.py>)

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ## **綜合演練**

# %% [markdown]
# ### 第一題
# #### 1.	某軟體只能處理附加檔名為jpg及png的圖形檔案，設計程式讓使用者輸入圖片檔案名稱，程式會檢查輸入的圖片檔格式是否可以處理。

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ### 第二題
# #### 2.	請以自訂函式方式設計， 讓使用者輸入以「平方公尺」為單位的房屋面積， 畫面會顯示以「坪」為單位的房屋面積 (1 平方公尺=0.3025坪)。

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ### 第三題
# #### 3.  以十二小時制 (上午、下午) 顯示現在時刻。

# %%
# YOUR CODE HERE

# %% [markdown]
# <br>

# %% [markdown]
# ### 第四題
# #### 4.	小華媽媽上菜市場買菜，找錢時她希望在1元、5元、10元、50元硬幣中找回最少的硬幣。小華就利用自訂函式幫媽媽寫了一個這樣的程式。

# %%
# YOUR CODE HERE
